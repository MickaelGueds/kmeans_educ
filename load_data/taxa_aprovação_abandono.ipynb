# %%
import pandas as pd
import numpy as np

# %%
df_taxa_aprovação_abandono = pd.read_excel('../data/taxa_aprovacao_abandono.xlsx')
cabecalho = df_taxa_aprovação_abandono.columns
filtro = (df_taxa_aprovação_abandono['Dependencia'] == 'Pública') & (df_taxa_aprovação_abandono['Localizacao'] == 'Total')
df_taxa_aprovação_abandono_final = df_taxa_aprovação_abandono[filtro]
df_taxa_aprovação_abandono_final

df_taxa_aprovação_abandono_final = df_taxa_aprovação_abandono[filtro]
df_taxa_aprovação_abandono_final
# Out:
#                  Cidades Taxa aprovados fundamental total   \
# 8                  Acauã                              99.9
# 17          Agricolândia                              99.2
# 29           Água Branca                              99.7
# 42    Alagoinha do Piauí                              96.6
# 53     Alegrete do Piauí                              99.3
# ...                  ...                               ...
# 2654       Várzea Branca                              89.5
# 2663       Várzea Grande                              94.2
# 2673         Vera Mendes                              96.8
# 2684  Vila Nova do Piauí                               100
# 2695         Wall Ferraz                              99.8
#
#      Taxa aprovados total EM Taxa de abandonos EF Taxa de abandonos EM  \
# 8                       99.1                    0                  0.9
# 17                       100                  0.6                    0
# 29                       100                    0                    0
# 42                      93.8                  1.5                  1.9
# 53                      96.6                  0.2                  3.4
# ...                      ...                  ...                  ...
# 2654                      98                  3.5                    2
# 2663                    97.7                  0.5                  2.3
# 2673                    96.3                  1.2                  2.8
# 2684                     100                    0                    0
# 2695                    90.8                  0.2                  3.8
#
#      Dependencia Localizacao
# 8        Pública       Total
# 17       Pública       Total
# 29       Pública       Total
# 42       Pública       Total
# 53       Pública       Total
# ...          ...         ...
# 2654     Pública       Total
# 2663     Pública       Total
# 2673     Pública       Total
# 2684     Pública       Total
# 2695     Pública       Total
#
# [224 rows x 7 columns]
