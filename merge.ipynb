# %%
import pandas as pd
from load_data import distorcao,enem_media,escola_por_1000,ideb,populacao_df,taxa_alfabetizacao,taxa_aprovacao_abandono
# Out:
#                 Cidades  taxa_escolas_por_habitante
# 0                 Acauã                    0.623053
# 1          Agricolândia                    0.404858
# 2           Água Branca                    0.398338
# 3    Alagoinha do Piauí                    0.733245
# 4     Alegrete do Piauí                    0.647389
# ..                  ...                         ...
# 219       Várzea Branca                    0.791296
# 220       Várzea Grande                    0.679194
# 221         Vera Mendes                    0.313972
# 222  Vila Nova do Piauí                    0.681431
# 223         Wall Ferraz                         NaN
#
# [224 rows x 2 columns]

# %%
df_distorcao = distorcao()
df_enem = enem_media()
df_escola = escola_por_1000()
df_ideb = ideb()
df_populacao = populacao_df()
df_alfabetizacao = taxa_alfabetizacao()
df_aprovacao_abandono = taxa_aprovacao_abandono()

# %%
resultado = df_distorcao
resultado = resultado.merge(df_enem, on='Cidades', how='outer')
resultado = resultado.merge(df_escola, on='Cidades', how='outer')
resultado = resultado.merge(df_ideb, on='Cidades', how='outer')
resultado = resultado.merge(df_populacao, on='Cidades', how='outer')
resultado = resultado.merge(df_alfabetizacao, on='Cidades', how='outer')
resultado = resultado.merge(df_aprovacao_abandono, on='Cidades', how='outer')
resultado
# Out:
#                 Cidades tx_distorcao_medio tx_distorcao_fundamental  \
# 0                 Acauã               21.5                     10.2
# 1          Agricolândia               22.1                     14.2
# 2    Alagoinha do Piauí               16.4                     10.3
# 3     Alegrete do Piauí               13.9                      8.6
# 4            Alto Longá               25.8                     10.1
# ..                  ...                ...                      ...
# 219  Vila Nova do Piauí                 20                      9.4
# 220       Várzea Branca               37.7                     26.2
# 221       Várzea Grande               23.3                     11.2
# 222         Wall Ferraz               25.4                     17.1
# 223         Água Branca               10.9                      5.9
#
#      Media_Enem  taxa_escolas_por_habitante  ideb_ano_final  \
# 0           NaN                    0.623053             5.6
# 1           NaN                    0.404858             5.2
# 2           NaN                    0.733245             5.7
# 3           NaN                    0.647389             5.0
# 4           NaN                    0.816084             5.0
# ..          ...                         ...             ...
# 219         NaN                    0.681431             6.0
# 220         NaN                    0.791296             3.7
# 221         NaN                    0.679194             4.7
# 222         NaN                         NaN             4.9
# 223  485.885244                    0.398338             5.6
#
#      ideb_ensino_medio  ideb_ano_inicial  populacao  Idade  Total  \
# 0                  4.5               6.2     6420.0  Total  83,11
# 1                  4.9               5.2     4940.0  Total  78,97
# 2                  4.2               5.3     6819.0  Total  66,39
# 3                  4.4               5.8     4634.0  Total  70,79
# 4                  4.3               5.6    13479.0  Total  71,75
# ..                 ...               ...        ...    ...    ...
# 219                4.3               7.1     2935.0  Total  73,10
# 220                4.1               4.5     5055.0  Total  73,50
# 221                4.3               5.6     4417.0  Total  78,27
# 222                4.0               5.6        NaN  Total  71,13
# 223                4.1               6.8    17573.0  Total  84,94
#
#     Taxa aprovados fundamental total  Taxa aprovados total EM  \
# 0                                99.9                    99.1
# 1                                99.2                     100
# 2                                96.6                    93.8
# 3                                99.3                    96.6
# 4                                99.3                    89.5
# ..                                ...                     ...
# 219                               100                     100
# 220                              89.5                      98
# 221                              94.2                    97.7
# 222                              99.8                    90.8
# 223                              99.7                     100
#
#     Taxa de abandonos EF Taxa de abandonos EM Dependencia Localizacao
# 0                      0                  0.9     Pública       Total
# 1                    0.6                    0     Pública       Total
# 2                    1.5                  1.9     Pública       Total
# 3                    0.2                  3.4     Pública       Total
# 4                    0.1                  9.3     Pública       Total
# ..                   ...                  ...         ...         ...
# 219                    0                    0     Pública       Total
# 220                  3.5                    2     Pública       Total
# 221                  0.5                  2.3     Pública       Total
# 222                  0.2                  3.8     Pública       Total
# 223                    0                    0     Pública       Total
#
# [224 rows x 17 columns]
